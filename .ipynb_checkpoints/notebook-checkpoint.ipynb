# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** [Khairul Abid]
# - **Email:** [abdikhairul71@gmail.com]
# - **ID Dicoding:** [abdey_k]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pada musim apa jumlah penyewaan sepeda paling tinggi
# - bagaimana distribusi jam penggunaan sepeda per hari dalam seminggu?
# - Bagaimana perbandingan jumlah penyewaan sepeda antara hari kerja dan hari libur?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# membaca dataset day

# %%
day_df = pd.read_csv("data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# membaca dataset hour

# %%
hour_df = pd.read_csv("data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel 'day_df'

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# cek NULL values

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# cek data duplikat

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# describe data

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# #### Menilai tabel `hour_df`

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# cek NULL values

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# cek data duplikat

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# describe data

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# tidak ada null values dan duplikasi pada data

# %% [markdown]
# Mengubah obj menjadi tipe data datetime

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %%
day_df['dteday'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 731 entries, 0 to 730
# Series name: dteday
# Non-Null Count  Dtype
# --------------  -----
# 731 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 5.8 KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore 'day_df'

# %%
day_df.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %% [markdown]
# Berdasarkan parameter statistik diatas, diperoleh informasi dari kolom 'cnt' bahwa rata-rata pengguna sebanyak 4504, dengan rentang pengguna antara 22 sampai 8714 orang. Informasi ini menunjukkan variasi yang cukup besar dalam penggunaan sepeda, dengan jumlah pengguna yang bervariasi dari hari ke hari.

# %% [markdown]
# Mencoba Menganalisis Pengguna pada setiap musim

# %% [markdown]
# mendefenisikan nama setiap musim

# %%
season_analysis = day_df.iloc[:,[2,13,14,15]]
sea = ['springer', 'summer', 'fall', 'winter']
season_analysis['season'] = season_analysis['season'].replace([1,2,3,4],sea)
# Out:
# C:\Users\AvitA EssentiaL\AppData\Local\Temp\ipykernel_15956\115791840.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season_analysis['season'] = season_analysis['season'].replace([1,2,3,4],sea)

# %%
season_analysis
# Out:
#        season  casual  registered   cnt
# 0    springer     331         654   985
# 1    springer     131         670   801
# 2    springer     120        1229  1349
# 3    springer     108        1454  1562
# 4    springer      82        1518  1600
# ..        ...     ...         ...   ...
# 726  springer     247        1867  2114
# 727  springer     644        2451  3095
# 728  springer     159        1182  1341
# 729  springer     364        1432  1796
# 730  springer     439        2290  2729
#
# [731 rows x 4 columns]

# %% [markdown]
# Mengetahui jumlah pengguna berdasarkan season (musim)

# %%
season_analysis_result = season_analysis.groupby('season').sum()
season_analysis_result
# Out:
#           casual  registered      cnt
# season
# fall      226091      835038  1061129
# springer   60622      410726   471348
# summer    203522      715067   918589
# winter    129782      711831   841613

# %% [markdown]
# Berdasarkan informasi diatas, diketahui jumlah pengguna selama musim fall (gugur) sebesar 1.061.129, melebihi musim lainnya

# %% [markdown]
# Mencoba Menganalisis Holiday

# %%
holiday_analysis = day_df.iloc[:,[5,13,14,15]]
pd.unique(holiday_analysis['holiday'])
# Out:
# array([0, 1], dtype=int64)

# %%
holiday_analysis_result = holiday_analysis.groupby('holiday').sum()
holiday_analysis_result
# Out:
#          casual  registered      cnt
# holiday
# 0        597658     2616586  3214244
# 1         22359       56076    78435

# %% [markdown]
# jumlah pengguna sepeda pada saat hari libur (holiday) menurun. Hal ini terlihat dari perbandingan jumlah pengguna casual dan terdaftar (registered) antara hari biasa dan hari libur. Pada hari biasa (0), jumlah pengguna casual adalah 597,658 dan jumlah pengguna terdaftar adalah 2,616,586, sedangkan pada hari libur (1) jumlah pengguna casual turun menjadi 22,359 dan jumlah pengguna terdaftar turun menjadi 56,076.

# %% [markdown]
# ### Explore 'hour_df'

# %% [markdown]
# Melihat jumlah pengguna layanan bike sharing pada setiap jam

# %%
hour_analysis = hour_df.iloc[:,[5,14,15,16]]
hour_analysis_result = hour_analysis.groupby('hr').sum()
hour_analysis_result
# Out:
#     casual  registered     cnt
# hr
# 0     7375       31755   39130
# 1     4709       19455   24164
# 2     3412       12940   16352
# 3     1893        6281    8174
# 4      874        3554    4428
# 5     1012       13249   14261
# 6     3017       52115   55132
# 7     8037      146134  154171
# 8    15761      245240  261001
# 9    22458      136980  159438
# 10   33789       92468  126257
# 11   43286      108034  151320
# 12   49718      134696  184414
# 13   52713      132206  184919
# 14   55089      120563  175652
# 15   54606      128543  183149
# 16   53834      173914  227748
# 17   54220      282640  336860
# 18   44496      265276  309772
# 19   35505      191284  226789
# 20   26378      138172  164550
# 21   20570      104875  125445
# 22   16200       79412   95612
# 23   11065       52876   63941

# %% [markdown]
# Mengurutkan jumlah pengguna bike sharing terbanyak

# %%
hour_analysis_result_sorted = hour_analysis_result.sort_values(by='cnt', ascending=False)
print(hour_analysis_result_sorted)
# Out:
#     casual  registered     cnt
# hr
# 17   54220      282640  336860
# 18   44496      265276  309772
# 8    15761      245240  261001
# 16   53834      173914  227748
# 19   35505      191284  226789
# 13   52713      132206  184919
# 12   49718      134696  184414
# 15   54606      128543  183149
# 14   55089      120563  175652
# 20   26378      138172  164550
# 9    22458      136980  159438
# 7     8037      146134  154171
# 11   43286      108034  151320
# 10   33789       92468  126257
# 21   20570      104875  125445
# 22   16200       79412   95612
# 23   11065       52876   63941
# 6     3017       52115   55132
# 0     7375       31755   39130
# 1     4709       19455   24164
# 2     3412       12940   16352
# 5     1012       13249   14261
# 3     1893        6281    8174
# 4      874        3554    4428

# %% [markdown]
# Berdasarkan hasil tersebut, dapat diamati bahwa pada jam 17:00 (5 sore) memiliki jumlah pengguna tertinggi dengan total 336,860 pengguna. Hal ini menunjukkan bahwa jam 17:00 adalah salah satu waktu paling populer bagi pengguna bike sharing. Diikuti oleh jam 18:00 (6 sore) dengan total 309,772 pengguna.

# %% [markdown]
# ### Explore all data

# %% [markdown]
# #### Menghubungkan semua data

# %%
# Menggabungkan data day_df dan hour_df berdasarkan kolom 'dteday'
all_df = pd.merge(left=day_df, right=hour_df, how="inner", on="dteday")

# Melihat lima baris pertama dari data gabungan
all_df.head()
# Out:
#    instant_x     dteday  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 0          1 2011-01-01         1     0       1          0          6
# 1          1 2011-01-01         1     0       1          0          6
# 2          1 2011-01-01         1     0       1          0          6
# 3          1 2011-01-01         1     0       1          0          6
# 4          1 2011-01-01         1     0       1          0          6
#
#    workingday_x  weathersit_x    temp_x  ...  weekday_y  workingday_y  \
# 0             0             2  0.344167  ...          6             0
# 1             0             2  0.344167  ...          6             0
# 2             0             2  0.344167  ...          6             0
# 3             0             2  0.344167  ...          6             0
# 4             0             2  0.344167  ...          6             0
#
#    weathersit_y  temp_y  atemp_y  hum_y  windspeed_y  casual_y  registered_y  \
# ...

# %% [markdown]
# DataFrame baru yang berisi gabungan dari data day_df dan hour_df berdasarkan kolom 'dteday'. pd.merge, x dan y digunakan untuk menunjukkan sumber data yang berbeda yang akan digabungkan. x merujuk pada data dari DataFrame kiri (left DataFrame) yaitu tabel day_df, sedangkan y merujuk pada data dari DataFrame kanan (right DataFrame) yaitu tabel hour_df.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# - Pada musim apa jumlah penyewaan sepeda paling tinggi, dan bagaimana hubungannya dengan temperatur suhu?

# %%
all_df.sample(5)
# Out:
#        instant_x     dteday  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 12697        535 2012-06-18         2     1       6          0          1
# 9696         409 2012-02-13         1     1       2          0          1
# 1042          47 2011-02-16         1     0       2          0          3
# 9320         394 2012-01-29         1     1       1          0          0
# 12787        539 2012-06-22         3     1       6          0          5
#
#        workingday_x  weathersit_x    temp_x  ...  weekday_y  workingday_y  \
# 12697             1             2  0.568333  ...          1             1
# 9696              1             1  0.222500  ...          1             1
# 1042              1             1  0.318261  ...          3             1
# 9320              0             1  0.282500  ...          0             0
# 12787             1             1  0.777500  ...          5             1
#
#        weathersit_y  temp_y  atemp_y  hum_y  windspeed_y  casual_y  \
# ...

# %%
day_df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
most_used_season = all_df.groupby('season_x')['cnt_x'].sum().reset_index()

sea = {1: 'springer', 2: 'summer', 3: 'fall', 4: 'winter'}
most_used_season['season_x'].replace(sea, inplace=True)

most_used_season.rename(columns={'season_x': 'season', 'cnt_x': 'total_rentals'}, inplace=True)

most_used_season = most_used_season.sort_values(by='total_rentals', ascending=False)

most_used_season_str = most_used_season.to_string(index=False)
print(most_used_season_str)
# Out:
#   season  total_rentals
#     fall       25420803
#   summer       22024071
#   winter       20167029
# springer       11179147

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='season', y='total_rentals', data=most_used_season, palette='viridis')
plt.title('Total Penyewaan Sepeda berdasarkan Musim', fontsize=16)
plt.xlabel('Musim', fontsize=14)
plt.ylabel('Total Penyewaan Sepeda', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# C:\Users\AvitA EssentiaL\AppData\Local\Temp\ipykernel_15956\621883489.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='season', y='total_rentals', data=most_used_season, palette='viridis')

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# Bagaimana distribusi jam penggunaan sepeda per hari dalam seminggu?

# %%
hour_analysis_result_sorted = all_df.groupby('hr')['cnt_y'].sum().reset_index().sort_values(by='cnt_y', ascending=False).reset_index(drop=True)
hour_analysis_result_sorted
# Out:
#     hr   cnt_y
# 0   17  336860
# 1   18  309772
# 2    8  261001
# 3   16  227748
# 4   19  226789
# 5   13  184919
# 6   12  184414
# 7   15  183149
# 8   14  175652
# 9   20  164550
# 10   9  159438
# 11   7  154171
# 12  11  151320
# 13  10  126257
# 14  21  125445
# 15  22   95612
# 16  23   63941
# 17   6   55132
# 18   0   39130
# 19   1   24164
# 20   2   16352
# 21   5   14261
# 22   3    8174
# 23   4    4428

# %%
weekday_analysis_result_sorted = all_df.groupby('weekday_y')['cnt_y'].sum().reset_index().sort_values(by='cnt_y', ascending=False).reset_index(drop=True)
weekday_mapping = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}

# Mengganti nilai 'weekday_y' dengan nama hari yang sesuai
weekday_analysis_result_sorted['weekday_y'] = weekday_analysis_result_sorted['weekday_y'].map(weekday_mapping)

weekday_analysis_result_sorted
# Out:
#    weekday_y   cnt_y
# 0     Friday  487790
# 1   Thursday  485395
# 2   Saturday  477807
# 3  Wednesday  473048
# 4    Tuesday  469109
# 5     Monday  455503
# 6     Sunday  444027

# %%
hour_analysis_result_sorted = all_df.groupby(['weekday_y', 'hr'])['cnt_y'].sum().reset_index()
hour_analysis_result_sorted = hour_analysis_result_sorted.sort_values(by='cnt_y', ascending=False).reset_index(drop=True)
# Membuat kamus untuk mengganti nilai 'weekday_y' dengan nama hari yang sesuai
hour_analysis_result_sorted['weekday_y'] = hour_analysis_result_sorted['weekday_y'].map(weekday_mapping)
hour_analysis_result_sorted
# Out:
#      weekday_y  hr  cnt_y
# 0      Tuesday  17  56605
# 1     Thursday  17  54844
# 2      Tuesday  18  53827
# 3    Wednesday  17  53367
# 4       Monday  17  52249
# ..         ...  ..    ...
# 163   Thursday   3    497
# 164     Monday   3    496
# 165  Wednesday   3    484
# 166  Wednesday   4    477
# 167    Tuesday   3    382
#
# [168 rows x 3 columns]

# %%
# Plot grafik
plt.figure(figsize=(10, 6))
sns.barplot(x='hr', y='cnt_y', data=hour_analysis_result_sorted, palette='Set2')
plt.xlabel('Jam')
plt.ylabel('Jumlah Penyewaan Sepeda')
plt.title('Jumlah Penyewaan Sepeda per Jam')
plt.tight_layout()

# Tampilkan grafik
plt.show()
# Out:
# C:\Users\AvitA EssentiaL\AppData\Local\Temp\ipykernel_15956\1923770374.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='hr', y='cnt_y', data=hour_analysis_result_sorted, palette='Set2')

# %%
# Plot grafik
plt.figure(figsize=(10, 6))
sns.barplot(x='weekday_y', y='cnt_y', data=weekday_analysis_result_sorted, palette='Set2')
plt.xlabel('Hari')
plt.ylabel('Jumlah Penyewaan Sepeda')
plt.title('Jumlah Penyewaan Sepeda per Hari')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Tampilkan grafik
plt.show()
# Out:
# C:\Users\AvitA EssentiaL\AppData\Local\Temp\ipykernel_15956\845157862.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weekday_y', y='cnt_y', data=weekday_analysis_result_sorted, palette='Set2')

# %%
top_10_most_used_hour_per_day = hour_analysis_result_sorted.head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10_most_used_hour_per_day['hr'].astype(str) + '-' + top_10_most_used_hour_per_day['weekday_y'], top_10_most_used_hour_per_day['cnt_y'], color='skyblue')
plt.xlabel('Jam dan Hari')
plt.ylabel('Jumlah Pengguna')
plt.title('Distribusi jam penggunaan sepeda per hari dalam seminggu')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 3:

# %% [markdown]
# Bagaimana perbandingan jumlah penyewaan sepeda antara hari kerja dan hari libur?

# %%
rentals_comparison = all_df.groupby('workingday_y')['cnt_y'].sum().reset_index()
rentals_comparison['workingday_y'] = rentals_comparison['workingday_y'].replace({0: 'Hari Libur', 1: 'Hari Kerja'})
print(rentals_comparison)
# Out:
#   workingday_y    cnt_y
# 0   Hari Libur  1000269
# 1   Hari Kerja  2292410

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='cnt_y', y='workingday_y', data=rentals_comparison, palette='Set2')
plt.title('Perbandingan Jumlah Penyewaan Sepeda antara Hari Kerja dan Hari Libur', fontsize=16)
plt.xlabel('Jumlah Penyewaan Sepeda', fontsize=14)
plt.ylabel('Hari', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
# Out:
# C:\Users\AvitA EssentiaL\AppData\Local\Temp\ipykernel_15956\3041513802.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='cnt_y', y='workingday_y', data=rentals_comparison, palette='Set2')

# %% [markdown]
# ### RFM Analysis

# %%
# Menghitung Recency, Frequency, dan Monetary
recency_df = all_df.groupby('instant_x')['dteday'].max().reset_index()
recency_df['recency'] = (pd.to_datetime('2024-03-02') - recency_df['dteday']).dt.days

frequency_df = all_df.groupby('instant_x').size().reset_index(name='frequency')

monetary_df = all_df.groupby('instant_x')['cnt_y'].sum().reset_index()
monetary_df.rename(columns={'cnt_y': 'monetary'}, inplace=True)
monetary_df
# Out:
#      instant_x  monetary
# 0            1       985
# 1            2       801
# 2            3      1349
# 3            4      1562
# 4            5      1600
# ..         ...       ...
# 726        727      2114
# 727        728      3095
# 728        729      1341
# 729        730      1796
# 730        731      2729
#
# [731 rows x 2 columns]

# %%
# Menggabungkan Recency, Frequency, dan Monetary
rfm_df = pd.merge(recency_df, frequency_df, on='instant_x')
rfm_df = pd.merge(rfm_df, monetary_df, on='instant_x')
rfm_df
# Out:
#      instant_x     dteday  recency  frequency  monetary
# 0            1 2011-01-01     4809         24       985
# 1            2 2011-01-02     4808         23       801
# 2            3 2011-01-03     4807         22      1349
# 3            4 2011-01-04     4806         23      1562
# 4            5 2011-01-05     4805         23      1600
# ..         ...        ...      ...        ...       ...
# 726        727 2012-12-27     4083         24      2114
# 727        728 2012-12-28     4082         24      3095
# 728        729 2012-12-29     4081         24      1341
# 729        730 2012-12-30     4080         24      1796
# 730        731 2012-12-31     4079         24      2729
#
# [731 rows x 5 columns]

# %%
# Menghitung quartile untuk setiap RFM
rfm_quartiles = rfm_df[['recency', 'frequency', 'monetary']].quantile([0.25, 0.5, 0.75])
rfm_quartiles = rfm_quartiles.to_dict()
rfm_quartiles
# Out:
# {'recency': {0.25: 4261.5, 0.5: 4444.0, 0.75: 4626.5},
#  'frequency': {0.25: 24.0, 0.5: 24.0, 0.75: 24.0},
#  'monetary': {0.25: 3152.0, 0.5: 4548.0, 0.75: 5956.0}}

# %%
# Fungsi untuk mengkategorikan RFM
def rfm_segment(row):
    if row['recency'] <= rfm_quartiles['recency'][0.25]:
        r_score = 4
    elif row['recency'] <= rfm_quartiles['recency'][0.50]:
        r_score = 3
    elif row['recency'] <= rfm_quartiles['recency'][0.75]:
        r_score = 2
    else:
        r_score = 1
    
    if row['frequency'] <= rfm_quartiles['frequency'][0.25]:
        f_score = 1
    elif row['frequency'] <= rfm_quartiles['frequency'][0.50]:
        f_score = 2
    elif row['frequency'] <= rfm_quartiles['frequency'][0.75]:
        f_score = 3
    else:
        f_score = 4
        
    if row['monetary'] <= rfm_quartiles['monetary'][0.25]:
        m_score = 1
    elif row['monetary'] <= rfm_quartiles['monetary'][0.50]:
        m_score = 2
    elif row['monetary'] <= rfm_quartiles['monetary'][0.75]:
        m_score = 3
    else:
        m_score = 4
    
    return str(r_score) + str(f_score) + str(m_score)

# Menambahkan kolom RFM segment
rfm_df['rfm_segment'] = rfm_df.apply(rfm_segment, axis=1)

# Menambahkan kolom RFM score
rfm_df['rfm_score'] = rfm_df[['recency', 'frequency', 'monetary']].sum(axis=1)

# Menampilkan hasil RFM analysis
print(rfm_df.head())
# Out:
#    instant_x     dteday  recency  frequency  monetary rfm_segment  rfm_score
# 0          1 2011-01-01     4809         24       985         111       5818
# 1          2 2011-01-02     4808         23       801         111       5632
# 2          3 2011-01-03     4807         22      1349         111       6178
# 3          4 2011-01-04     4806         23      1562         111       6391
# 4          5 2011-01-05     4805         23      1600         111       6428

# %%
# Plot distribusi Recency
plt.figure(figsize=(8, 4))
plt.hist(rfm_df['recency'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribusi Recency')
plt.xlabel('Recency (days)')
plt.ylabel('Frequency')
plt.show()

# Plot distribusi Frequency
plt.figure(figsize=(8, 4))
plt.hist(rfm_df['frequency'], bins=20, color='salmon', edgecolor='black')
plt.title('Distribusi Frequency')
plt.xlabel('Frequency')
plt.ylabel('Frequency')
plt.show()

# Plot distribusi Monetary
plt.figure(figsize=(8, 4))
plt.hist(rfm_df['monetary'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribusi Monetary')
plt.xlabel('Monetary')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * Pada musim apa jumlah penyewaan sepeda paling tinggi
#   > Berdasarkan data, jumlah penyewaan sepeda tertinggi terjadi pada musim fall (gugur), sebanyak  25.420.803 total peminjaman, diikuti oleh musim summer (panas) sebanyak  22.024.071, musim winter (dingin) sebanyak 20.167.029, dan terendah pada musim spring (semi) 11.179.147. Ini menunjukkan bahwa musim gugur menjadi musim yang paling diminati untuk menggunakan layanan bike sharing.
# * bagaimana distribusi jam penggunaan sepeda per hari dalam seminggu?
#   > Dari data yang diperoleh, terlihat bahwa jam paling sering digunakan untuk bersepeda adalah pada hari Selasa dan Kamis pukul 17:00 dengan jumlah penyewaan sepeda tertinggi, yaitu 56.605 dan 54.844, secara berturut-turut. Kesimpulan dari hasil analisis ini adalah bahwa jam-jam paling populer untuk penggunaan sepeda adalah di sore hari, terutama pada hari kerja seperti Selasa dan Kamis. Hal ini menunjukkan bahwa sebagian besar penggunaan sepeda terjadi ketika orang-orang kembali dari pekerjaan atau melakukan aktivitas pada hari kerja. Selain itu, ada tren peningkatan penggunaan sepeda pada hari Jumat dibandingkan dengan hari-hari lainnya, yang mungkin karena faktor-faktor seperti akhir pekan atau liburan.
# * Bagaimana perbandingan jumlah penyewaan sepeda antara hari kerja dan hari libur?
#   > Dari hasil analisis, terlihat bahwa jumlah penyewaan sepeda pada hari kerja (Hari Kerja) jauh lebih tinggi daripada pada hari libur (Hari Libur). Pada hari kerja, terdapat total 2.292.410 penyewaan sepeda, sedangkan pada hari libur, jumlah penyewaannya hanya sebesar 1.000.269. Hal ini menunjukkan bahwa sepeda lebih sering disewa pada hari kerja daripada pada hari libur.

# %%
all_df.to_csv("all_data.csv", index=False)
